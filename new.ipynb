# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
import glob
import os
import pandas as pd

# %%
sample_type = "easy"
data = pd.read_csv("metadata/seg_examples.csv")
path_list = []

# Include all the paths
# for i in data['path']:
#     path_list.append(i)

# Include just the hard examples
for i in data.loc[data['type'] == sample_type, 'path']:
    path_list.append(i)

# %%
path_list
# Out:
# ['binary/train/nevus/nev00001.jpg',
#  'binary/train/nevus/nev00002.jpg',
#  'binary/train/nevus/nev00016.jpg',
#  'binary/train/nevus/nev00176.jpg',
#  'binary/train/others/ack00132.jpg',
#  'binary/train/others/ack00208.jpg',
#  'binary/train/others/bcc00169.jpg',
#  'binary/train/others/bkl00076.jpg',
#  'binary/train/others/bkl01513.jpg',
#  'binary/train/others/mel00101.jpg',
#  'binary/train/others/mel00269.jpg',
#  'binary/train/others/mel02479.jpg',
#  'binary/train/others/vac00061.jpg',
#  'three_class/train/scc/scc00061.jpg']

# %%
pwd
# Out:
# 'C:\\Users\\Lenovo\\PycharmProjects\\Skin_lesion_segmentation'

# %%
img = cv2.imread("data/"+path_list[0])
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
img_lab = cv2.cvtColor(img, cv2.COLOR_BGR2LAB)
img_ycrcb = cv2.cvtColor(img, cv2.COLOR_BGR2YCrCb)
img_hsv = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)

# %%
plt.imshow(img_rgb[:,:,0])

# %%
f, ax = plt.subplots(3, 4, figsize=(10,10))
ax[0, 0].imshow(img_rgb[:,:,0])
ax[0, 0].axis('off')
ax[0, 0].set_title("RGB-R")
ax[1, 0].imshow(img_rgb[:,:,1])
ax[1, 0].axis('off')
ax[1, 0].set_title("RGB-G")
ax[2, 0].imshow(img_rgb[:,:,2])
ax[2, 0].axis('off')
ax[2, 0].set_title("RGB-B")

ax[0, 1].imshow(img_lab[:,:,0])
ax[0, 1].axis('off')
ax[0, 1].set_title("LAB-L")
ax[1, 1].imshow(img_lab[:,:,1])
ax[1, 1].axis('off')
ax[1, 1].set_title("LAB-A")
ax[2, 1].imshow(img_lab[:,:,2])
ax[2, 1].axis('off')
ax[2, 1].set_title("LAB-B")

ax[0, 2].imshow(img_ycrcb[:,:,0])
ax[0, 2].axis('off')
ax[0, 2].set_title("YCrCb-Y")
ax[1, 2].imshow(img_ycrcb[:,:,1])
ax[1, 2].axis('off')
ax[1, 2].set_title("YCrCb-Cr")
ax[2, 2].imshow(img_ycrcb[:,:,2])
ax[2, 2].axis('off')
ax[2, 2].set_title("YCrCb-Cb")

ax[0, 3].imshow(img_hsv[:,:,0])
ax[0, 3].axis('off')
ax[0, 3].set_title("HSV-H")
ax[1, 3].imshow(img_hsv[:,:,1])
ax[1, 3].axis('off')
ax[1, 3].set_title("HSV-S")
ax[2, 3].imshow(img_hsv[:,:,2])
ax[2, 3].axis('off')
ax[2, 3].set_title("HSV-V")

plt.show()
