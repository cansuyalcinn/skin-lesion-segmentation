# %%
import os
import sys; sys.path.insert(0, os.path.abspath("../"))
import cv2
import numpy as np 
import matplotlib.pyplot as plt
# from utils.plots import get_image, get_image_and_plot
from tqdm import tqdm
import pandas as pd
from dataset.dataset import SkinLesion_Dataset

# %%
os.getcwd()
# Out:
# '/home/alex/Documents/MAIA/udG/CAD/Skin_lesion_segmentation/notebooks'

# %%
# define dataset class, default binary
data = SkinLesion_Dataset()
len(data)
# Out:
# 18991

# %%
# get item of a single data
sample = data[0]
sample.keys()
# Out:
# dict_keys(['idx', 'label', 'img'])

# %%
plt.imshow(sample['img'])
