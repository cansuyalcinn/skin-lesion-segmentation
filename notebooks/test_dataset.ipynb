# %%
import os
import sys; sys.path.insert(0, os.path.abspath("../"))
import cv2
import numpy as np 
import matplotlib.pyplot as plt
# from utils.plots import get_image, get_image_and_plot
from tqdm import tqdm
import pandas as pd
from dataset.dataset import SkinLesion_Dataset, SegExamples

# %%
# define dataset class, default binary
data = SkinLesion_Dataset()
len(data)
# Out:
# 18991

# %%
# get item of a single data
sample = data[0]
sample.keys()
# Out:
# dict_keys(['idx', 'label', 'img'])

# %%
plt.imshow(sample['img'])

# %% [markdown]
# ### Segmentation examples

# %%
examples = SegExamples()
len(examples.seg_examples_df)
# Out:
# 68

# %%
examples.seg_examples_df
# Out:
#                                   path    type
# 0      binary/train/nevus/nev00001.jpg    easy
# 1      binary/train/nevus/nev00002.jpg    easy
# 2      binary/train/nevus/nev00016.jpg    easy
# 3      binary/train/nevus/nev00023.jpg  medium
# 4      binary/train/nevus/nev00036.jpg    hard
# ..                                 ...     ...
# 63  three_class/train/scc/scc00147.jpg    hard
# 64  three_class/train/scc/scc00224.jpg  medium
# 65  three_class/train/scc/scc00296.jpg   vhard
# 66  three_class/train/scc/scc00337.jpg   vhard
# 67  three_class/train/scc/scc00376.jpg    hard
#
# [68 rows x 2 columns]

# %%
examples[0].keys()
# Out:
# dict_keys(['idx', 'type', 'problem', 'label', 'img'])

# %%
plt.imshow(examples[1]['img'])
print(examples[1]['type'])
# Out:
# easy
